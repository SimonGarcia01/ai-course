# %% [markdown]
# <img src="https://user-images.githubusercontent.com/7065401/58563302-42466a80-8201-11e9-9948-b3e9f88a5662.jpg"
#     style="width:400px; float: right; margin: 0 40px 40px 40px;"></img>
#
#
# ## Bike store sales

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Manos a la obra

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
sales = pd.read_csv(
    'sales_data.csv',
    parse_dates=['Date'])

# %%
#mostrar las dimensiones del dataframe
sales.shape
# Out:
# (113036, 18)

# %%
#mostrar la cabecera del dataframe
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  datetime64[ns]
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
#mostrar la descripción del dataframe
sales.describe()
# Out:
#                                 Date            Day           Year  \
# count                         113036  113036.000000  113036.000000
# mean   2014-11-23 12:14:55.063519232      15.665753    2014.401739
# min              2011-01-01 00:00:00       1.000000    2011.000000
# 25%              2013-12-22 00:00:00       8.000000    2013.000000
# 50%              2014-06-27 00:00:00      16.000000    2014.000000
# 75%              2016-01-09 00:00:00      23.000000    2016.000000
# max              2016-07-31 00:00:00      31.000000    2016.000000
# std                              NaN       8.781567       1.272510
#
#         Customer_Age  Order_Quantity      Unit_Cost     Unit_Price  \
# count  113036.000000   113036.000000  113036.000000  113036.000000
# mean       35.919212       11.901660     267.296366     452.938427
# min        17.000000        1.000000       1.000000       2.000000
# 25%        28.000000        2.000000       2.000000       5.000000
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Cual es la media de  `Customers_Age`?

# %%
dfCustomerAge = sales["Customer_Age"]

# %% [markdown]
# Usar `.mean()`

# %%
dfCustomerAge.mean()
# Out:
# np.float64(35.91921157861212)

# %% [markdown]
# Mostrar una grafica tipo: <b>density (KDE)</b> y un  <b>box plot</b> para`Customer_Age` :

# %%
dfCustomerAge.plot(kind="kde", title="Density", figsize=(14,6))
# Out:
# <Axes: title={'center': 'Density'}, ylabel='Density'>

# %%
dfCustomerAge.plot(kind='box', title="Boxplot", vert=False, figsize=(16,4))
# Out:
# <Axes: title={'center': 'Boxplot'}>

# %%
# Out:
# <Axes: ylabel='Density'>

# %%
# Out:
# <Axes: >

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Calcular la media de `Order_Quantity`?

# %%
dfOrderQuantity = sales["Order_Quantity"]

# %%
print(dfOrderQuantity.mean())
# Out:
# 11.901659648253654

# %% [markdown]
# Mostrar un <b>histogram</b> y un <b>box plot</b> para `Order_Quantity` :

# %%
dfOrderQuantity.plot(kind="hist" ,figsize=(16,4))
# Out:
# <Axes: ylabel='Frequency'>

# %%
dfOrderQuantity.plot(kind="box", vert=False, figsize=(16,4))
# Out:
# <Axes: >

# %%
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Cuantas ventas al año tenemos?

# %%
print(sales['Year'].value_counts())
# Out:
# Year
# 2016    29398
# 2014    29398
# 2015    24443
# 2013    24443
# 2012     2677
# 2011     2677
# Name: count, dtype: int64

# %%
# Out:
# Year
# 2014    29398
# 2016    29398
# 2013    24443
# 2015    24443
# 2012     2677
# 2011     2677
# Name: count, dtype: int64

# %% [markdown]
# Mostrar un <b>pie plot</b> usando los datos anteriores (año):

# %%
sales['Year'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Cuantas ventas tenemos por mes?

# %%
sales['Month'].value_counts()
# Out:
# Month
# June         11234
# December     11200
# May          11128
# April        10182
# March         9674
# January       9284
# February      9022
# October       8750
# November      8734
# August        8200
# September     8166
# July          7462
# Name: count, dtype: int64

# %%
# Out:
# Month
# June         11234
# December     11200
# May          11128
# April        10182
# March         9674
# January       9284
# February      9022
# October       8750
# November      8734
# August        8200
# September     8166
# July          7462
# Name: count, dtype: int64

# %% [markdown]
# Mostrar un <b>bar plot</b> con las ventas por mes:

# %%
sales['Month'].value_counts().plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='Month'>

# %%
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Que pais tiene la mayor cantidad de ventas `quantity of sales`?

# %%
sales['Country'].value_counts()
# Out:
# Country
# United States     39206
# Australia         23936
# Canada            14178
# United Kingdom    13620
# Germany           11098
# France            10998
# Name: count, dtype: int64

# %%
# Out:
# Country
# United States     39206
# Australia         23936
# Canada            14178
# United Kingdom    13620
# Germany           11098
# France            10998
# Name: count, dtype: int64

# %% [markdown]
# Mostrar un <b>bar plot</b> de ventas por pais:

# %%
sales['Country'].value_counts().plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='Country'>

# %%
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Crear una lista de los productos vendidos

# %%
sales['Product'].unique()
# Out:
# array(['Hitch Rack - 4-Bike', 'All-Purpose Bike Stand',
#        'Mountain Bottle Cage', 'Water Bottle - 30 oz.',
#        'Road Bottle Cage', 'AWC Logo Cap', 'Bike Wash - Dissolver',
#        'Fender Set - Mountain', 'Half-Finger Gloves, L',
#        'Half-Finger Gloves, M', 'Half-Finger Gloves, S',
#        'Sport-100 Helmet, Black', 'Sport-100 Helmet, Red',
#        'Sport-100 Helmet, Blue', 'Hydration Pack - 70 oz.',
#        'Short-Sleeve Classic Jersey, XL',
#        'Short-Sleeve Classic Jersey, L', 'Short-Sleeve Classic Jersey, M',
#        'Short-Sleeve Classic Jersey, S', 'Long-Sleeve Logo Jersey, M',
#        'Long-Sleeve Logo Jersey, XL', 'Long-Sleeve Logo Jersey, L',
#        'Long-Sleeve Logo Jersey, S', 'Mountain-100 Silver, 38',
#        'Mountain-100 Silver, 44', 'Mountain-100 Black, 48',
#        'Mountain-100 Silver, 48', 'Mountain-100 Black, 38',
#        'Mountain-200 Silver, 38', 'Mountain-100 Black, 44',
# ...

# %%
#usar   .unique()
# Out:
# array(['Hitch Rack - 4-Bike', 'All-Purpose Bike Stand',
#        'Mountain Bottle Cage', 'Water Bottle - 30 oz.',
#        'Road Bottle Cage', 'AWC Logo Cap', 'Bike Wash - Dissolver',
#        'Fender Set - Mountain', 'Half-Finger Gloves, L',
#        'Half-Finger Gloves, M', 'Half-Finger Gloves, S',
#        'Sport-100 Helmet, Black', 'Sport-100 Helmet, Red',
#        'Sport-100 Helmet, Blue', 'Hydration Pack - 70 oz.',
#        'Short-Sleeve Classic Jersey, XL',
#        'Short-Sleeve Classic Jersey, L', 'Short-Sleeve Classic Jersey, M',
#        'Short-Sleeve Classic Jersey, S', 'Long-Sleeve Logo Jersey, M',
#        'Long-Sleeve Logo Jersey, XL', 'Long-Sleeve Logo Jersey, L',
#        'Long-Sleeve Logo Jersey, S', 'Mountain-100 Silver, 38',
#        'Mountain-100 Silver, 44', 'Mountain-100 Black, 48',
#        'Mountain-100 Silver, 48', 'Mountain-100 Black, 38',
#        'Mountain-200 Silver, 38', 'Mountain-100 Black, 44',
# ...

# %% [markdown]
# Crear un **bar plot** mostrando los 10 productos más vendidos (best sellers):

# %%
sales.groupby('Product')['Order_Quantity'].sum().sort_values(ascending=False).head(10).plot(kind='bar',figsize=(14,6))
# Out:
# <Axes: xlabel='Product'>

# %%
# Out:
# <Axes: xlabel='Product'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Observa alguna relación entre `Unit_Cost` y `Unit_Price`?
#
# Mostrar un <b>scatter plot</b> entre las dos columnas.

# %% [markdown]
# # Si

# %%
plt.figure(figsize=(6,6))
plt.scatter(x=sales['Unit_Cost'], y=sales['Unit_Price'])
plt.xlabel("Unit_Cost")
plt.ylabel("Unit_Price")
plt.show()

# %%
# Out:
# <Axes: xlabel='Unit_Cost', ylabel='Unit_Price'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Observa alguna relación entre `Order_Quantity` y `Profit`?
#
# Mostrar un <b>scatter plot</b> entre las dos columnas.

# %% [markdown]
# # Si

# %%
sales.plot(x='Order_Quantity', y='Profit', kind='scatter')
# Out:
# <Axes: xlabel='Order_Quantity', ylabel='Profit'>

# %%
# Out:
# <Axes: xlabel='Order_Quantity', ylabel='Profit'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Observa alguna relación entre `Profit` por `Country`?
#
# Mostrar un <b>box plot</b> agrupado por pais con las ganancias.

# %% [markdown]
# # No

# %%
sales[['Profit', 'Country']].boxplot(by='Country', figsize=(14,6))
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='[Country]'>

# %%
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='[Country]'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Observa alguna relación entre `Customer_Age` por `Country`?
#
# Mostrar un <b>box plot</b> agrupando pais y la edad de los clientes.

# %% [markdown]
# # No

# %%
sales[['Customer_Age', 'Country']].boxplot(by='Country', figsize=(14,6))
# Out:
# <Axes: title={'center': 'Customer_Age'}, xlabel='[Country]'>

# %%
# Out:
# <Axes: title={'center': 'Customer_Age'}, xlabel='[Country]'>

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
